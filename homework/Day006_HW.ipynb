# %% [markdown]
# # API 資料串接 - 以 知乎 API 實作範例
#
#
#
# * 了解知乎 API 使用方式與回傳內容
# * 撰寫程式存取 API 且添加標頭

# %% [markdown]
# ## 作業目標
#
# * 根據範例提供的 API ，完成以下問題：
#
#     1. 取出知乎問題發問時間
#     2. 取出第一筆與最後一筆回答的時間

# %% [markdown]
# ### 1. 取出知乎問題發問時間

# %%
# 1. 取出知乎問題發問時間
import json
import requests
from datetime import datetime

headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get('https://www.zhihu.com/api/v4/questions/55493026/answers',headers=headers)
response = r.text

data = json.loads(response)
for thread in data['data']:
  timestamp = thread['created_time']
  human_readable_time = datetime.fromtimestamp(timestamp)
  print(human_readable_time)
# Out:
# 2019-05-14 09:00:12
# 2017-05-02 06:48:23
# 2019-04-01 02:17:08
# 2017-05-02 02:45:13
# 2019-10-29 03:07:06

# %% [markdown]
# ### 2. 取出第一筆與最後一筆回答的時間

# %%
# 2. 取出第一筆與最後一筆回答的時間
import json
import requests
from datetime import datetime


headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get('https://www.zhihu.com/api/v4/questions/55493026/answers',headers=headers)
response = r.text

data = json.loads(response)
threads = data['data']
first_answer_time = datetime.fromtimestamp(threads[0]['created_time'])
last_answer_time = datetime.fromtimestamp(threads[-1]['created_time'])

print(first_answer_time)
print(last_answer_time)
# Out:
# 2019-05-14 09:00:12
# 2019-10-29 03:07:06
